# %%
import numpy as np
import cmath
import random
import matplotlib.pyplot as plt
def first(x,Bin,g):
    r = []
    a = complex(0.1,2*x)
    b = complex(1,2*x)
    for i in g:
            ratio = (-1 + ((2*a)/(4*g*g + a*b)))
            r.append(ratio.real)
    ra=np.array(r)
    return ratio
g = np.arange(start = 0.215,stop = 0.235,step = 0.001)
#plt.plot(g,first(0.01,0,g),label = 'theoretical spectra without noise g = 0.225')
#plt.plot(g,first(0.02,0,g),label = 'theoretical spectra without noise g = 0.225')
plt.plot(g,first(0.01,0,g),label = 'theoretical spectra without noise g = 0.225')
plt.ylabel("Re(A_out/B_in)")
plt.xlabel("g(g_EP = 0.225)")
plt.show()
# Out:
# C:\Users\91969\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
